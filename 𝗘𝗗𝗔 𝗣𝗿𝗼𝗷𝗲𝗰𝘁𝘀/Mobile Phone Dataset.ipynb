# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.offline as px

# %%
data = pd.read_csv(r"C:\Users\shobh\OneDrive\Attachments\Documents\Desktop\py\Mobiles Dataset (2025).csv", encoding = 'latin-1')

df = pd.DataFrame(data)

# %%
shape = df.shape

print("Data Set have ",shape[0]," rows and total",shape[1],"column")

print("\n All Coloumns :\n",df.columns)

print(type(df))

print(df.info())

print(df.describe)
# Out:
# Data Set have  930  rows and total 15 column
#
#  All Coloumns :
#  Index(['Company Name', 'Model Name', 'Mobile Weight', 'RAM', 'Front Camera',
#        'Back Camera', 'Processor', 'Battery Capacity', 'Screen Size',
#        'Launched Price (Pakistan)', 'Launched Price (India)',
#        'Launched Price (China)', 'Launched Price (USA)',
#        'Launched Price (Dubai)', 'Launched Year'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 930 entries, 0 to 929
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Company Name               930 non-null    object
#  1   Model Name                 930 non-null    object
#  2   Mobile Weight              930 non-null    object
#  3   RAM                        930 non-null    object
#  4   Front Camera               930 non-null    object
# ...

# %%
print(df.info())


print(df.isnull().sum())

print(df.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 930 entries, 0 to 929
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Company Name               930 non-null    object
#  1   Model Name                 930 non-null    object
#  2   Mobile Weight              930 non-null    object
#  3   RAM                        930 non-null    object
#  4   Front Camera               930 non-null    object
#  5   Back Camera                930 non-null    object
#  6   Processor                  930 non-null    object
#  7   Battery Capacity           930 non-null    object
#  8   Screen Size                930 non-null    object
#  9   Launched Price (Pakistan)  930 non-null    object
#  10  Launched Price (India)     930 non-null    object
#  11  Launched Price (China)     930 non-null    object
#  12  Launched Price (USA)       930 non-null    object
# ...

# %%
df.sample()
# Out:
#     Company Name       Model Name Mobile Weight   RAM Front Camera  \
# 534       Xiaomi  Xiaomi 14 256GB          189g  12GB         32MP
#
#                          Back Camera           Processor Battery Capacity  \
# 534  50MP (Main) + 50MP (Ultra-wide)  Snapdragon 8 Gen 3         4,610mAh
#
#      Screen Size Launched Price (Pakistan) Launched Price (India)  \
# 534  6.36 inches               PKR 169,999             INR 74,999
#
#     Launched Price (China) Launched Price (USA) Launched Price (Dubai)  \
# 534              CNY 3,999              USD 699              AED 2,899
#
#      Launched Year
# 534           2023

# %%
price = df[['Launched Price (Pakistan)', 'Launched Price (China)','Launched Price (USA)','Launched Price (Dubai)']]

price.info()

#Extracting currency symbols


price = df[['Launched Price (Pakistan)', 'Launched Price (China)','Launched Price (USA)','Launched Price (Dubai)']]



final = price.apply(lambda x:  str(x).split(" ")[3])

final
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 930 entries, 0 to 929
# Data columns (total 4 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Launched Price (Pakistan)  930 non-null    object
#  1   Launched Price (China)     930 non-null    object
#  2   Launched Price (USA)       930 non-null    object
#  3   Launched Price (Dubai)     930 non-null    object
# dtypes: object(4)
# memory usage: 29.2+ KB
# Launched Price (Pakistan)
# Launched Price (China)
# Launched Price (USA)
# Launched Price (Dubai)
# dtype: object

# %%
df.sample()
# Out:
#     Company Name   Model Name Mobile Weight   RAM Front Camera Back Camera  \
# 770      Infinix  Note 40 Pro          190g  12GB         32MP       108MP
#
#                    Processor Battery Capacity  Screen Size  \
# 770  MediaTek Dimensity 8100         5,000mAh  6.78 inches
#
#     Launched Price (Pakistan) Launched Price (India) Launched Price (China)  \
# 770                PKR 59,999             INR 22,999              CNY 2,199
#
#     Launched Price (USA) Launched Price (Dubai)  Launched Year
# 770              USD 329              AED 1,199           2024

# %%
price = df['Launched Price (India)'].apply(lambda x : str(x))

price

final = df['Launched Price (India)'].apply(lambda x : x.split(" ")[1])

final 


slot = df['Launched Price (India)'].apply(lambda x : x.remove(","))

slot
# price = df['Launched Price (India)'].astype(int)

# print(converted)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 10
#       5 final = df['Launched Price (India)'].apply(lambda x : x.split(" ")[1])
#       7 final
# ---> 10 slot = df['Launched Price (India)'].apply(lambda x : x.remove(","))
#      12 slot
#      13 # price = df['Launched Price (India)'].astype(int)
#      14
#      15 # print(converted)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4943, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4808 def apply(
#    4809     self,
#    4810     func: AggFuncType,
#    (...)   4815     **kwargs,
#    4816 ) -> DataFrame | Series:
#    4817     """
#    4818     Invoke function on values of Series.
#    4819
#    (...)   4934     dtype: float64
#    4935     """
#    4936     return SeriesApply(
#    4937         self,
#    4938         func,
# ...

# %%
p = "Python"

px = p.remove("y")

px
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 3
#       1 p = "Python"
# ----> 3 px = p.remove("y")
#       5 px
#
# AttributeError: 'str' object has no attribute 'remove'
